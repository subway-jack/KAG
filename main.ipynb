# %% [markdown]
# ## Create a project

# %%
# !knext project create --config_path ./kag_config.yaml

# %% [markdown]
# ## upload the schema to the knowledge base

# %%
# !cd SpatioScene && knext schema commit

# %% [markdown]
# ## split the data

# %%
# !python utils/split_motion_sample.py

# %% [markdown]
# ## upload the data to the server

# %%
# !cd SpatioScene/builder && python indexer.py

# %% [markdown]
# ## qa question

# %%
# !cd SpatioScene/solver && python qa.py
# Out:
# 2025-05-17 15:46:08 - INFO - root - found config file: /Users/subway/code/python/项目/KAG/KAG-master/SpatioScene/kag_config.yaml
# 2025-05-17 15:46:08 - INFO - root - Done init config from local file
# 2025-05-17 15:46:11 - INFO - kag.common.llm.openai_client - OpenAIClient max_tokens=4096
# 2025-05-17 15:46:18 - INFO - kag.common.llm.openai_client - OpenAIClient max_tokens=4096
# ...
